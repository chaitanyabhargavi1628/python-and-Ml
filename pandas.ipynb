# %%
import pandas as pd
pd=pd.read_csv("COVID19_line_list_data.csv")

# %%
pd.shape
# Out:
# (1085, 27)

# %%
pd.head()
# Out:
#    id  case_in_country reporting date  Unnamed: 3  \
# 0   1              NaN      1/20/2020         NaN
# 1   2              NaN      1/20/2020         NaN
# 2   3              NaN      1/21/2020         NaN
# 3   4              NaN      1/21/2020         NaN
# 4   5              NaN      1/21/2020         NaN
#
#                                              summary             location  \
# 0  First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
# 1  First confirmed imported COVID-19 pneumonia pa...             Shanghai
# 2  First confirmed imported cases in Zhejiang: pa...             Zhejiang
# 3  new confirmed imported COVID-19 pneumonia in T...              Tianjin
# 4  new confirmed imported COVID-19 pneumonia in T...              Tianjin
#
#   country  gender   age symptom_onset  ...  recovered symptom  \
# 0   China    male  66.0      01/03/20  ...          0     NaN
# 1   China  female  56.0     1/15/2020  ...          0     NaN
# ...

# %%
pd.columns
# Out:
# Index(['id', 'case_in_country', 'reporting date', 'Unnamed: 3', 'summary',
#        'location', 'country', 'gender', 'age', 'symptom_onset',
#        'If_onset_approximated', 'hosp_visit_date', 'exposure_start',
#        'exposure_end', 'visiting Wuhan', 'from Wuhan', 'death', 'recovered',
#        'symptom', 'source', 'link', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26'],
#       dtype='object')

# %%
type(pd.sample(1))
# Out:
# pandas.core.frame.DataFrame

# %%
pd.dtypes
# Out:
# id                         int64
# case_in_country          float64
# reporting date            object
# Unnamed: 3               float64
# summary                   object
# location                  object
# country                   object
# gender                    object
# age                      float64
# symptom_onset             object
# If_onset_approximated    float64
# hosp_visit_date           object
# exposure_start            object
# exposure_end              object
# visiting Wuhan             int64
# from Wuhan               float64
# death                     object
# recovered                 object
# symptom                   object
# source                    object
# link                      object
# Unnamed: 21              float64
# Unnamed: 22              float64
# Unnamed: 23              float64
# Unnamed: 24              float64
# Unnamed: 25              float64
# Unnamed: 26              float64
# dtype: object

# %%
pd.isnull().sum() #null values
# Out:
# id                          0
# case_in_country           197
# reporting date              1
# Unnamed: 3               1085
# summary                     5
# location                    0
# country                     0
# gender                    183
# age                       242
# symptom_onset             522
# If_onset_approximated     525
# hosp_visit_date           578
# exposure_start            957
# exposure_end              744
# visiting Wuhan              0
# from Wuhan                  4
# death                       0
# recovered                   0
# symptom                   815
# source                      0
# link                        0
# Unnamed: 21              1085
# Unnamed: 22              1085
# Unnamed: 23              1085
# Unnamed: 24              1085
# Unnamed: 25              1085
# Unnamed: 26              1085
# dtype: int64

# %%
pd=pd.drop(['id','Unnamed: 21', 'Unnamed: 22','Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26'],axis=1)

# %%
pd.head()
# Out:
#    case_in_country reporting date  Unnamed: 3  \
# 0              NaN      1/20/2020         NaN
# 1              NaN      1/20/2020         NaN
# 2              NaN      1/21/2020         NaN
# 3              NaN      1/21/2020         NaN
# 4              NaN      1/21/2020         NaN
#
#                                              summary             location  \
# 0  First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
# 1  First confirmed imported COVID-19 pneumonia pa...             Shanghai
# 2  First confirmed imported cases in Zhejiang: pa...             Zhejiang
# 3  new confirmed imported COVID-19 pneumonia in T...              Tianjin
# 4  new confirmed imported COVID-19 pneumonia in T...              Tianjin
#
#   country  gender   age symptom_onset  If_onset_approximated hosp_visit_date  \
# 0   China    male  66.0      01/03/20                    0.0        01/11/20
# 1   China  female  56.0     1/15/2020                    0.0       1/15/2020
# ...

# %%
pd.values
# Out:
# array([[nan, '1/20/2020', nan, ..., nan,
#         'Shenzhen Municipal Health Commission',
#         'http://wjw.sz.gov.cn/wzx/202001/t20200120_18987787.htm'],
#        [nan, '1/20/2020', nan, ..., nan,
#         'Official Weibo of Shanghai Municipal Health Commission',
#         'https://www.weibo.com/2372649470/IqogQhgfa?from=page_1001062372649470_profile&wvr=6&mod=weibotime&type=comment'],
#        [nan, '1/21/2020', nan, ..., nan,
#         'Health Commission of Zhejiang Province',
#         'http://www.zjwjw.gov.cn/art/2020/1/21/art_1202101_41786033.html'],
#        ...,
#        [1.0, '2/26/2020', nan, ..., nan, 'South China Morning Post',
#         'https://www.scmp.com/news/china/society/article/3052457/algeria-reports-first-coronavirus-case-italian-citizen'],
#        [1.0, '2/25/2020', nan, ..., nan, 'Reuters',
#         'https://www.reuters.com/article/us-croatia-coronavirus/croatia-confirms-its-first-case-of-coronavirus-infection-idUSKBN20J1OB'],
# ...

# %%
pd.select_dtypes("object")
# Out:
#      reporting date                                            summary  \
# 0         1/20/2020  First confirmed imported COVID-19 pneumonia pa...
# 1         1/20/2020  First confirmed imported COVID-19 pneumonia pa...
# 2         1/21/2020  First confirmed imported cases in Zhejiang: pa...
# 3         1/21/2020  new confirmed imported COVID-19 pneumonia in T...
# 4         1/21/2020  new confirmed imported COVID-19 pneumonia in T...
# ...             ...                                                ...
# 1080      2/25/2020  new COVID-19 patient confirmed in Austria: 24,...
# 1081      2/24/2020  new COVID-19 patient confirmed in Afghanistan:...
# 1082      2/26/2020  new COVID-19 patient confirmed in Algeria: mal...
# 1083      2/25/2020  new COVID-19 patient confirmed in Croatia: mal...
# 1084      2/25/2020  new COVID-19 patient confirmed in Switzerland:...
#
#                  location      country  gender symptom_onset hosp_visit_date  \
# ...

# %%
print(pd.shape[0])#To check the number of rows
print(pd.shape[1])# TO get the number of columns
# Out:
# 1085
# 20

# %%
#To access the datatype of particular column
print(pd.dtypes[2])
print(pd.dtypes[-1])
# Out:
# float64
# object

# %%
pd1=pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 20 columns):
# case_in_country          888 non-null float64
# reporting date           1084 non-null object
# Unnamed: 3               0 non-null float64
# summary                  1080 non-null object
# location                 1085 non-null object
# country                  1085 non-null object
# gender                   902 non-null object
# age                      843 non-null float64
# symptom_onset            563 non-null object
# If_onset_approximated    560 non-null float64
# hosp_visit_date          507 non-null object
# exposure_start           128 non-null object
# exposure_end             341 non-null object
# visiting Wuhan           1085 non-null int64
# from Wuhan               1081 non-null float64
# death                    1085 non-null object
# recovered                1085 non-null object
# symptom                  270 non-null object
# ...

# %% [markdown]
# # specific column DataType

# %% [markdown]
# - dataframe object does'nt have dtype
# - series object have dtype and dtypes

# %%
# numericla columns

# %%
pd.age.mean() #mean
# Out:
# 49.483689205219456

# %%
pd.age.mode()[0]
# Out:
# 55.0

# %%
(pd.age.min(),pd.age.max()) #min,max functions
# Out:
# (0.25, 96.0)

# %%
#objec datatype
pd.country.dtype
# Out:
# dtype('O')

# %%
pd.country.count()
# Out:
# 1085

# %%
pd.country.unique()
# Out:
# array(['China', 'France', 'Japan', 'Malaysia', 'Nepal', 'Singapore',
#        'South Korea', 'Taiwan', 'Thailand', 'USA', 'Vietnam', 'Australia',
#        'Canada', 'Cambodia', 'Sri Lanka', 'Germany', 'UAE', 'Hong Kong',
#        'Italy', 'Russia', 'UK', 'India', 'Phillipines', 'Finland',
#        'Spain', 'Sweden', 'Belgium', 'Egypt', 'Iran', 'Israel', 'Lebanon',
#        'Kuwait', 'Bahrain', 'Austria', 'Afghanistan', 'Algeria',
#        'Croatia', 'Switzerland'], dtype=object)

# %%
#how many unique country 
pd.country.nunique()
# Out:
# 38

# %%
pd.country.value_counts()
# Out:
# China          197
# Japan          190
# South Korea    114
# Hong Kong       94
# Singapore       93
# Germany         54
# Thailand        41
# France          39
# Taiwan          34
# Spain           34
# Malaysia        23
# UAE             21
# UK              20
# USA             18
# Iran            18
# Bahrain         17
# Vietnam         16
# Australia       15
# Canada          12
# Kuwait           9
# Phillipines      3
# India            3
# Italy            3
# Austria          2
# Russia           2
# Lebanon          1
# Algeria          1
# Switzerland      1
# Belgium          1
# Cambodia         1
# Sweden           1
# Israel           1
# Egypt            1
# Sri Lanka        1
# Finland          1
# Croatia          1
# Afghanistan      1
# Nepal            1
# Name: country, dtype: int64

# %%
print(pd.country.unique()) # Unique countries
print(pd.index) # Indexes
# Out:
# ['China' 'France' 'Japan' 'Malaysia' 'Nepal' 'Singapore' 'South Korea'
#  'Taiwan' 'Thailand' 'USA' 'Vietnam' 'Australia' 'Canada' 'Cambodia'
#  'Sri Lanka' 'Germany' 'UAE' 'Hong Kong' 'Italy' 'Russia' 'UK' 'India'
#  'Phillipines' 'Finland' 'Spain' 'Sweden' 'Belgium' 'Egypt' 'Iran'
#  'Israel' 'Lebanon' 'Kuwait' 'Bahrain' 'Austria' 'Afghanistan' 'Algeria'
#  'Croatia' 'Switzerland']
# RangeIndex(start=0, stop=1085, step=1)

# %%
pd.describe()
# Out:
#        case_in_country  Unnamed: 3         age  If_onset_approximated  \
# count       888.000000         0.0  843.000000             560.000000
# mean         48.841216         NaN   49.483689               0.042857
# std          78.853528         NaN   18.255334               0.202716
# min           1.000000         NaN    0.250000               0.000000
# 25%          11.000000         NaN   35.000000               0.000000
# 50%          28.000000         NaN   51.000000               0.000000
# 75%          67.250000         NaN   64.000000               0.000000
# max        1443.000000         NaN   96.000000               1.000000
#
#        visiting Wuhan   from Wuhan
# count     1085.000000  1081.000000
# mean         0.176959     0.144311
# std          0.381810     0.351567
# min          0.000000     0.000000
# 25%          0.000000     0.000000
# 50%          0.000000     0.000000
# 75%          0.000000     0.000000
# max          1.000000     1.000000

# %%
pd.describe(include=object) #to get the description for tthe categorical column
# Out:
#        reporting date                                         summary  \
# count            1084                                            1080
# unique             43                                             967
# top         2/27/2020  new confirmed COVID-19 patient in South Korea:
# freq               91                                              22
#
#            location country gender symptom_onset hosp_visit_date  \
# count          1085    1085    902           563             507
# unique          156      38      2            70              60
# top     South Korea   China   male     1/23/2020       1/23/2020
# freq            112     197    520            27              34
#
#        exposure_start exposure_end death recovered symptom  \
# count             128          341  1085      1085     270
# unique             39           52    14        32     108
# top         1/26/2020    1/22/2020     0         0   fever
# ...

# %%
import numpy as np
pd.describe(include=np.int64)
# Out:
#        visiting Wuhan
# count     1085.000000
# mean         0.176959
# std          0.381810
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000

# %% [markdown]
# # slicing,subsettind,boolean Indexing
# - position Based Index(iloc)
#     - rows
#     - columns
# - Label Based Indexing(loc)

# %%
pd.iloc[1,:]
# Out:
# case_in_country                                                        NaN
# reporting date                                                   1/20/2020
# Unnamed: 3                                                             NaN
# summary                  First confirmed imported COVID-19 pneumonia pa...
# location                                                          Shanghai
# country                                                              China
# gender                                                              female
# age                                                                     56
# symptom_onset                                                    1/15/2020
# If_onset_approximated                                                    0
# hosp_visit_date                                                  1/15/2020
# exposure_start                                                         NaN
# ...

# %%
pd.iloc[1,5] #row with 1 and 5 column
# Out:
# 'China'

# %%
pd.set_index("country").head(3) #To set particular column as index
# Out:
#          case_in_country reporting date  Unnamed: 3  \
# country
# China                NaN      1/20/2020         NaN
# China                NaN      1/20/2020         NaN
# China                NaN      1/21/2020         NaN
#
#                                                    summary  \
# country
# China    First confirmed imported COVID-19 pneumonia pa...
# China    First confirmed imported COVID-19 pneumonia pa...
# China    First confirmed imported cases in Zhejiang: pa...
#
#                     location  gender   age symptom_onset  \
# country
# China    Shenzhen, Guangdong    male  66.0      01/03/20
# China               Shanghai  female  56.0     1/15/2020
# China               Zhejiang    male  46.0      01/04/20
#
#          If_onset_approximated hosp_visit_date exposure_start exposure_end  \
# country
# China                      0.0        01/11/20     12/29/2019     01/04/20
# China                      0.0       1/15/2020            NaN     01/12/20
# ...

# %%
#row wit index1 and all the columns
pd.iloc[1:2,:]
# Out:
#    case_in_country reporting date  Unnamed: 3  \
# 1              NaN      1/20/2020         NaN
#
#                                              summary  location country  \
# 1  First confirmed imported COVID-19 pneumonia pa...  Shanghai   China
#
#    gender   age symptom_onset  If_onset_approximated hosp_visit_date  \
# 1  female  56.0     1/15/2020                    0.0       1/15/2020
#
#   exposure_start exposure_end  visiting Wuhan  from Wuhan death recovered  \
# 1            NaN     01/12/20               0         1.0     0         0
#
#   symptom                                             source  \
# 1     NaN  Official Weibo of Shanghai Municipal Health Co...
#
#                                                 link
# 1  https://www.weibo.com/2372649470/IqogQhgfa?fro...

# %%
# row with indices 1,2,3
pd.iloc[1:4,:]
# Out:
#    case_in_country reporting date  Unnamed: 3  \
# 1              NaN      1/20/2020         NaN
# 2              NaN      1/21/2020         NaN
# 3              NaN      1/21/2020         NaN
#
#                                              summary  location country  \
# 1  First confirmed imported COVID-19 pneumonia pa...  Shanghai   China
# 2  First confirmed imported cases in Zhejiang: pa...  Zhejiang   China
# 3  new confirmed imported COVID-19 pneumonia in T...   Tianjin   China
#
#    gender   age symptom_onset  If_onset_approximated hosp_visit_date  \
# 1  female  56.0     1/15/2020                    0.0       1/15/2020
# 2    male  46.0      01/04/20                    0.0       1/17/2020
# 3  female  60.0           NaN                    NaN       1/19/2020
#
#   exposure_start exposure_end  visiting Wuhan  from Wuhan death recovered  \
# 1            NaN     01/12/20               0         1.0     0         0
# ...

# %%
print(pd.isnull())
# Out:
#       case_in_country  reporting date  Unnamed: 3  summary  location  country  \
# 0                True           False        True    False     False    False
# 1                True           False        True    False     False    False
# 2                True           False        True    False     False    False
# 3                True           False        True    False     False    False
# 4                True           False        True    False     False    False
# ...               ...             ...         ...      ...       ...      ...
# 1080            False           False        True    False     False    False
# 1081            False           False        True    False     False    False
# 1082            False           False        True    False     False    False
# 1083            False           False        True    False     False    False
# 1084            False           False        True    False     False    False
#
# ...

# %%
print(pd.isnull().sum()) #null values in each column
# Out:
# case_in_country           197
# reporting date              1
# Unnamed: 3               1085
# summary                     5
# location                    0
# country                     0
# gender                    183
# age                       242
# symptom_onset             522
# If_onset_approximated     525
# hosp_visit_date           578
# exposure_start            957
# exposure_end              744
# visiting Wuhan              0
# from Wuhan                  4
# death                       0
# recovered                   0
# symptom                   815
# source                      0
# link                        0
# dtype: int64
