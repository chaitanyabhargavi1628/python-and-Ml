# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
report=pd.read_csv("https://raw.githubusercontent.com/sumathi16/Machine-Learning-March/master/FL_insurance_sample.csv")

# %%
report.shape
# Out:
# (36634, 18)

# %%
print(report.columns)
type(report.columns)
# Out:
# Index(['policyID', 'statecode', 'county', 'eq_site_limit', 'hu_site_limit',
#        'fl_site_limit', 'fr_site_limit', 'tiv_2011', 'tiv_2012',
#        'eq_site_deductible', 'hu_site_deductible', 'fl_site_deductible',
#        'fr_site_deductible', 'point_latitude', 'point_longitude', 'line',
#        'construction', 'point_granularity'],
#       dtype='object')
# pandas.core.indexes.base.Index

# %%
report.index
# Out:
# RangeIndex(start=0, stop=36634, step=1)

# %%
report.head(3)
# Out:
#    policyID statecode       county  eq_site_limit  hu_site_limit  \
# 0    119736        FL  CLAY COUNTY       498960.0       498960.0
# 1    448094        FL  CLAY COUNTY      1322376.3      1322376.3
# 2    206893        FL  CLAY COUNTY       190724.4       190724.4
#
#    fl_site_limit  fr_site_limit   tiv_2011    tiv_2012  eq_site_deductible  \
# 0       498960.0       498960.0   498960.0   792148.90                 0.0
# 1      1322376.3      1322376.3  1322376.3  1438163.57                 0.0
# 2       190724.4       190724.4   190724.4   192476.78                 0.0
#
#    hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude  \
# 0              9979.2                 0.0                   0       30.102261
# 1                 0.0                 0.0                   0       30.063936
# 2                 0.0                 0.0                   0       30.089579
#
#    point_longitude         line construction  point_granularity
# ...

# %%
report.isna().sum()  # checking for null values
# Out:
# policyID              0
# statecode             0
# county                0
# eq_site_limit         0
# hu_site_limit         0
# fl_site_limit         0
# fr_site_limit         0
# tiv_2011              0
# tiv_2012              0
# eq_site_deductible    0
# hu_site_deductible    0
# fl_site_deductible    0
# fr_site_deductible    0
# point_latitude        0
# point_longitude       0
# line                  0
# construction          0
# point_granularity     0
# dtype: int64

# %%
from sklearn import preprocessing
lb=preprocessing.LabelEncoder()
report['statecode']=lb.fit_transform(report['statecode'])
report['county']=lb.fit_transform(report['county'])
report
# Out:
#        policyID  statecode  county  eq_site_limit  hu_site_limit  \
# 0        119736          0       9       498960.0      498960.00
# 1        448094          0       9      1322376.3     1322376.30
# 2        206893          0       9       190724.4      190724.40
# 3        333743          0       9            0.0       79520.76
# 4        172534          0       9            0.0      254281.50
# ...         ...        ...     ...            ...            ...
# 36629    404309          0      52            0.0       88722.00
# 36630    465875          0      52      1297057.5     1297057.50
# 36631    791209          0      52       173286.9      173286.90
# 36632    322627          0      52      1499781.6     1499781.60
# 36633    398149          0      52       373488.3      373488.30
#
#        fl_site_limit  fr_site_limit    tiv_2011    tiv_2012  \
# 0           498960.0       498960.0   498960.00   792148.90
# 1          1322376.3      1322376.3  1322376.30  1438163.57
# ...

# %%
print(type(report["point_latitude"]))
print(report["point_latitude"])
# Out:
# <class 'pandas.core.series.Series'>
# 0        30.102261
# 1        30.063936
# 2        30.089579
# 3        30.063236
# 4        30.060614
#            ...
# 36629    28.122885
# 36630    28.080900
# 36631    28.110550
# 36632    28.089415
# 36633    28.064440
# Name: point_latitude, Length: 36634, dtype: float64

# %%
report.point_latitude.value_counts() # To check for the repetition of the each value
# Out:
# 30.334900    116
# 25.610620     88
# 30.207600     87
# 30.614815     70
# 25.863385     63
#             ...
# 26.957880      1
# 25.963270      1
# 28.201950      1
# 26.181790      1
# 30.658001      1
# Name: point_latitude, Length: 17900, dtype: int64

# %%
# x=report.point_latitude
# y=report.point_granularity
# plt.bar(x,y)
# plt.title("point_latitude vs point_granularity")
# plt.xlabel("point_granularity")
# plt.ylabel("point_latitude")

# %%
x=report.point_latitude
x
# Out:
# 0        30.102261
# 1        30.063936
# 2        30.089579
# 3        30.063236
# 4        30.060614
#            ...
# 36629    28.122885
# 36630    28.080900
# 36631    28.110550
# 36632    28.089415
# 36633    28.064440
# Name: point_latitude, Length: 36634, dtype: float64

# %%
report
# Out:
#        policyID  statecode  county  eq_site_limit  hu_site_limit  \
# 0        119736          0       9       498960.0      498960.00
# 1        448094          0       9      1322376.3     1322376.30
# 2        206893          0       9       190724.4      190724.40
# 3        333743          0       9            0.0       79520.76
# 4        172534          0       9            0.0      254281.50
# ...         ...        ...     ...            ...            ...
# 36629    404309          0      52            0.0       88722.00
# 36630    465875          0      52      1297057.5     1297057.50
# 36631    791209          0      52       173286.9      173286.90
# 36632    322627          0      52      1499781.6     1499781.60
# 36633    398149          0      52       373488.3      373488.30
#
#        fl_site_limit  fr_site_limit    tiv_2011    tiv_2012  \
# 0           498960.0       498960.0   498960.00   792148.90
# 1          1322376.3      1322376.3  1322376.30  1438163.57
# ...

# %%
y=report.point_latitude
x=report.point_granularity
plt.scatter(x,y)
plt.show("log")

# %%
numerical_cols = report.columns[report.dtypes != object]
numerical_cols
# Out:
# Index(['policyID', 'statecode', 'county', 'eq_site_limit', 'hu_site_limit',
#        'fl_site_limit', 'fr_site_limit', 'tiv_2011', 'tiv_2012',
#        'eq_site_deductible', 'hu_site_deductible', 'fl_site_deductible',
#        'fr_site_deductible', 'point_latitude', 'point_longitude',
#        'point_granularity'],
#       dtype='object')

# %%
for val in range((report.dtypes!='object').sum()):
    plt.subplot(4,4,val+1)
    plt.boxplot(report[numerical_cols[val]])
    plt.yscale("log")
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   after removing the cwd from sys.path.
# C:\Users\dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   after removing the cwd from sys.path.

# %%
print(report[numerical_cols[1]])
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 36629    0
# 36630    0
# 36631    0
# 36632    0
# 36633    0
# Name: statecode, Length: 36634, dtype: int64

# %%
report_sc=report.copy()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
sc=MinMaxScaler()
sc.fit(report[['hu_site_limit']])
report_sc[["hu_site_limit"]]=sc.transform(report[['hu_site_limit']])

# %%
report_sc
# Out:
#        policyID  statecode  county  eq_site_limit  hu_site_limit  \
# 0        119736          0       9       498960.0       0.000231
# 1        448094          0       9      1322376.3       0.000612
# 2        206893          0       9       190724.4       0.000088
# 3        333743          0       9            0.0       0.000037
# 4        172534          0       9            0.0       0.000118
# ...         ...        ...     ...            ...            ...
# 36629    404309          0      52            0.0       0.000041
# 36630    465875          0      52      1297057.5       0.000600
# 36631    791209          0      52       173286.9       0.000080
# 36632    322627          0      52      1499781.6       0.000694
# 36633    398149          0      52       373488.3       0.000173
#
#        fl_site_limit  fr_site_limit    tiv_2011    tiv_2012  \
# 0           498960.0       498960.0   498960.00   792148.90
# 1          1322376.3      1322376.3  1322376.30  1438163.57
# ...
